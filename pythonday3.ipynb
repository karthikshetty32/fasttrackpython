# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
a = input("Enter the sentence ")

print(a.islower())
print(a.capitalize())
print(a.center(50))
print(a.isupper())
print(a.isspace())
print(a.isalpha())
print(a.isalnum())
print(a.isascii())
print(a.split())
print(a.strip())
# Out:
# Enter the sentence hello Buddy
# False
# Hello buddy
#                    hello Buddy
# False
# False
# False
# False
# True
# ['hello', 'Buddy']
# hello Buddy

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
a = [500.45, 499.56,476.54,600.45]

f = ["karthik", 4.73, "shetty", 2.68, "ram", 5.71, "raja", 7.89]

festival = ['ganesha', 'dasara', 'diwali']

num = [100, 101, 102]

a1 = [59]
b1 = [60]

a.sort()
print(a)

print(type(f))

festival.append('xmas')
print(festival)

num.extend([104, 105])
print(num)

print(festival.index('dasara'))

print(max(a))

print(min(a))

print(len(festival))

print(list(festival))

print(f.pop())
# Out:
# [476.54, 499.56, 500.45, 600.45]
# <class 'list'>
# ['ganesha', 'dasara', 'diwali', 'xmas']
# [100, 101, 102, 104, 105]
# 1
# 600.45
# 476.54
# 4
# ['ganesha', 'dasara', 'diwali', 'xmas']
# 7.89

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
a = ('k','a','r','t','h','i','k')

mixed_type = ('C','H',0,'c',0)

mytuple = (1, 1, [3,4])

numbers1 = (0,1,2,3,4,5)

numbers2 = (6,7,8)


print(type(a))

for i in mixed_type:
    print(i,":",type(i))

print(id(mytuple[0]) == id(mytuple[1]))

print(numbers1[-1])

print(numbers1[1:4])

sum = numbers1 + numbers2 
print(sum)

mul = numbers2*2
print(mul)

print(mytuple.count(1))

print(len(numbers1))

print(a.index('r'))
# Out:
# <class 'tuple'>
# C : <class 'str'>
# H : <class 'str'>
# 0 : <class 'int'>
# c : <class 'str'>
# 0 : <class 'int'>
# True
# 5
# (1, 2, 3)
# (0, 1, 2, 3, 4, 5, 6, 7, 8)
# (6, 7, 8, 6, 7, 8)
# 2
# 6
# 2

# %%
dir(dict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
x = {}

x['first'] = 'apple'
x['second'] = 'mango'
x['third'] = 'banana'

print(type(x))

print(x)

print(len(x))

a = x.update({'second':'strawberry'})
print(a)

print(dict.fromkeys(x))

del x['third']
print(x)

print(x.items())

x.update({'fourth':'watermelon'})
print(x)

print(x.clear())

names = {'Ram': 18,'Cherry':12,'Tin':22,'Rocco':25}	
print("Students Name: %s" % names.items())
# Out:
# <class 'dict'>
# {'first': 'apple', 'second': 'mango', 'third': 'banana'}
# 3
# None
# {'first': None, 'second': None, 'third': None}
# {'first': 'apple', 'second': 'strawberry'}
# dict_items([('first', 'apple'), ('second', 'strawberry')])
# {'first': 'apple', 'second': 'strawberry', 'fourth': 'watermelon'}
# None
# Students Name: dict_items([('Ram', 18), ('Cherry', 12), ('Tin', 22), ('Rocco', 25)])

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
a = int (input ("Enter the first number: \n"))
b = int (input ("Enter the second number: \n"))

print (type (a),"\n",type(b))

print (pow (a, b)) 
print (abs (a)) 
print (a.bit_length())
print ("Number in hexadecimal is: ",hex (a))
print ("Number in Octal is: ",oct (a))

c =str (a)
print (type (c), c)

d = float(a)
print (type (d), d)

import sys
print ("Size of integer variable is :",sys.getsizeof(a))
# Out:
# Enter the first number:
# 34
# Enter the second number:
# 45
# <class 'int'>
#  <class 'int'>
# 825184889837725994971915471173621692744697928074424045623011467853824
# 34
# 6
# Number in hexadecimal is:  0x22
# Number in Octal is:  0o42
# <class 'str'> 34
# <class 'float'> 34.0
# Size of integer variable is : 28

# %%
dir(float)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__set_format__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
a = float (input ("Enter the first floating number: \n"))
b = float (input ("Enter the second floating number: \n"))

print (type (a),"\n",type(b))

print (pow (a, b)) 

print (abs (a)) 
c =str (a)
print (type (c), c)

d = int(a)
print (type (d), d)

decimal_points = int(input("Enter the number of decimal points to display:\n"))
print (round(a ,decimal_points))

import sys
print ("Size of floating variable is :",sys.getsizeof(a))
# Out:
# Enter the first floating number:
# 39.56
# Enter the second floating number:
# 49.46
# <class 'float'>
#  <class 'float'>
# 1.0006812294800049e+79
# 39.56
# <class 'str'> 39.56
# <class 'int'> 39
# Enter the number of decimal points to display:
# 4
# 39.56
# Size of floating variable is : 24
